# %%
pip install langchain langchain-openai langchain-community langchain-weaviate openai tiktoken unstructured pillow-heif unstructured-inference pytesseract unstructured-pytesseract pymupdf
# Out:
# ...
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.2 MB 2.0 MB/s eta 0:00:04
#    ---------------------------------------- 0.1/8.2 MB 1.2 MB/s eta 0:00:08
#    - -------------------------------------- 0.2/8.2 MB 1.9 MB/s eta 0:00:05
#    -- ------------------------------------- 0.4/8.2 MB 2.7 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.9/8.2 MB 4.4 MB/s eta 0:00:02
#    ------- -------------------------------- 1.6/8.2 MB 6.3 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.3/8.2 MB 8.1 MB/s eta 0:00:01
#    ------------- -------------------------- 2.8/8.2 MB 8.1 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.6/8.2 MB 9.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.6/8.2 MB 9.2 MB/s eta 0:00:01
#    -------------------- ------------------- 4.2/8.2 MB 8.6 MB/s eta 0:00:01
# ...

# %%
pip install opensearch-py
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/311.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/311.2 kB ? eta -:--:--
#    - -------------------------------------- 10.2/311.2 kB ? eta -:--:--
#    ----- --------------------------------- 41.0/311.2 kB 393.8 kB/s eta 0:00:01
#    ----------- --------------------------- 92.2/311.2 kB 655.4 kB/s eta 0:00:01
#    -------------------------- ------------- 204.8/311.2 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 311.2/311.2 kB 1.4 MB/s eta 0:00:00
# ...

# %%
pip install nltk rake_nltk
# Out:
# ...
#
# ...
